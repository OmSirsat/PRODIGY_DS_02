# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_data=pd.read_csv('/content/titanictrain.csv')
test_data=pd.read_csv('/content/titanictest.csv')

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.countplot(x='Survived', data=train_data)
plt.title('Survival Count')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
train_data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sb.countplot(x='Sex', hue='Survived', data=train_data)
plt.title('Survival Count by Gender')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %%
sb.countplot(x='Pclass', hue='Survived', data=train_data)
plt.title('Pclass: Survived vs Dead')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()

# %%
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_42b95_row0_col0, #T_42b95_row0_col1, #T_42b95_row0_col3, #T_42b95_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_42b95_row0_col2, #T_42b95_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_42b95_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_42b95_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_42b95_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_42b95_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_42b95_row2_col1, #T_42b95_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_42b95_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_42b95_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_42b95_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_42b95_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_42b95_row4_col0, #T_42b95_row4_col1, #T_42b95_row4_col2, #T_42b95_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42b95" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_42b95_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_42b95_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_42b95_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_42b95_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42b95_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_42b95_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_42b95_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_42b95_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_42b95_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_42b95_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_42b95_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_42b95_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_42b95_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_42b95_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_42b95_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_42b95_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_42b95_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_42b95_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_42b95_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_42b95_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_42b95_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_42b95_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_42b95_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_42b95_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_42b95_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_42b95_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_42b95_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_42b95_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_42b95_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_42b95_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_42b95_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_42b95_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
pip install factorplot
# Out:
# ERROR: Could not find a version that satisfies the requirement factorplot (from versions: none)
# ERROR: No matching distribution found for factorplot

# %%
sb.catplot(x='Pclass', y='Survived', hue='Sex', data=train_data, kind='bar')
plt.title('Survival Rate by Pclass and Sex')
plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.show()

# %%
print('Oldest person Survived was of:',train_data['Age'].max())
print('Youngest person Survived was of:',train_data['Age'].min())
print('Average person Survived was of:',train_data['Age'].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 29.69911764705882

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# Bar plot for Pclass and Age vs Survived
sb.barplot(x='Pclass', y='Age', hue='Survived', data=train_data, ax=ax[0])
ax[0].set_title('PClass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

# Bar plot for Sex and Age vs Survived
sb.barplot(x='Sex', y='Age', hue='Survived', data=train_data, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))

plt.show()

# %%
train_data['Initial']=0
for i in train_data:
    train_data['Initial']=train_data.Name.str.extract('([A-Za-z]+)\.') #extracting Name initials

# %%
pd.crosstab(train_data.Initial,train_data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5aaa3_row0_col0, #T_5aaa3_row0_col1, #T_5aaa3_row0_col3, #T_5aaa3_row0_col4, #T_5aaa3_row0_col5, #T_5aaa3_row0_col7, #T_5aaa3_row0_col8, #T_5aaa3_row0_col12, #T_5aaa3_row0_col15, #T_5aaa3_row0_col16, #T_5aaa3_row1_col2, #T_5aaa3_row1_col6, #T_5aaa3_row1_col9, #T_5aaa3_row1_col10, #T_5aaa3_row1_col11, #T_5aaa3_row1_col13, #T_5aaa3_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5aaa3_row0_col2, #T_5aaa3_row0_col6, #T_5aaa3_row0_col9, #T_5aaa3_row0_col10, #T_5aaa3_row0_col11, #T_5aaa3_row0_col13, #T_5aaa3_row0_col14, #T_5aaa3_row1_col0, #T_5aaa3_row1_col1, #T_5aaa3_row1_col3, #T_5aaa3_row1_col4, #T_5aaa3_row1_col5, #T_5aaa3_row1_col7, #T_5aaa3_row1_col8, #T_5aaa3_row1_col12, #T_5aaa3_row1_col15, #T_5aaa3_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5aaa3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_5aaa3_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_5aaa3_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_5aaa3_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_5aaa3_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_5aaa3_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_5aaa3_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_5aaa3_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_5aaa3_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_5aaa3_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_5aaa3_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_5aaa3_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_5aaa3_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_5aaa3_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_5aaa3_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_5aaa3_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_5aaa3_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_5aaa3_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5aaa3_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_5aaa3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5aaa3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5aaa3_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_5aaa3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5aaa3_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_5aaa3_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_5aaa3_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_5aaa3_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_5aaa3_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5aaa3_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_5aaa3_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_5aaa3_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_5aaa3_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_5aaa3_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_5aaa3_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_5aaa3_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_5aaa3_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5aaa3_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_5aaa3_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_5aaa3_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_5aaa3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_5aaa3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_5aaa3_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_5aaa3_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_5aaa3_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_5aaa3_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_5aaa3_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_5aaa3_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_5aaa3_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_5aaa3_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_5aaa3_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_5aaa3_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_5aaa3_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_5aaa3_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_5aaa3_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess',
                               'Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss',
                                'Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Other'),'Age']=46

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,20))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived = 1')
plt.show()

# %%
sb.catplot(x='Pclass', y='Survived', hue='Initial', kind='bar', data=train_data, col='Initial', height=4, aspect=0.7)
plt.subplots_adjust(top=0.8)  # Adjust the top space to accommodate the title
plt.suptitle('Survived by Pclass and Initial')
plt.show()

# %%
pd.crosstab([train_data.SibSp],train_data.Survived).style.background_gradient('summer_r')
# Out:
# <style type="text/css">
# #T_4e976_row0_col0, #T_4e976_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_4e976_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_4e976_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_4e976_row2_col0, #T_4e976_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_4e976_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_4e976_row3_col0, #T_4e976_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_4e976_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_4e976_row5_col0, #T_4e976_row5_col1, #T_4e976_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4e976_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_4e976" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_4e976_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_4e976_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e976_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e976_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_4e976_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e976_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_4e976_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e976_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_4e976_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e976_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_4e976_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e976_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_4e976_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e976_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_4e976_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4e976_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_4e976_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_4e976_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 8))

# Bar plot for SibSp vs Survived (without hue)
sb.barplot(x='SibSp', y='Survived', data=train_data, ax=ax[0])
ax[0].set_title('SibSp vs Survived in Bar Plot')

# Bar plot for SibSp vs Survived (with hue)
sb.barplot(x='SibSp', y='Survived', hue='Sex', data=train_data, ax=ax[1])
ax[1].set_title('SibSp vs Survived with hue')
plt.legend(title='Sex', loc='upper right')  # Add a legend for the hue

plt.show()

# %%
cross_tab = pd.crosstab(train_data.SibSp, train_data.Pclass)

# Create a heatmap
plt.figure(figsize=(10, 6))
sb.heatmap(cross_tab, annot=True, fmt='d', cmap='summer_r')
plt.title('SibSp vs Pclass (Cross-tabulation)')
plt.xlabel('Pclass')
plt.ylabel('SibSp')
plt.show()
